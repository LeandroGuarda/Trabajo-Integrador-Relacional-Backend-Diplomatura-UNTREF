# %%
import json

# Función para extraer categorías y géneros únicos del JSON
def extraer_categorias_y_generos(json_file):
    with open(json_file, 'r', encoding='utf-8') as file:
        datos = json.load(file)

    categorias = set()
    generos = set()

    for entrada in datos:
        categorias.add(entrada['categoria'])
        generos.update(entrada['genero'].split(', '))

    return list(categorias), list(generos)

# Función para generar consultas INSERT para categorías y géneros
def generar_inserts_categorias_generos(categorias, generos):
    consultas_categoria = []
    consultas_genero = []

    for idx, categoria in enumerate(categorias, start=1):
        categoria = categoria.replace("'", "''")
        consultas_categoria.append(f"INSERT INTO categorias (id, nombre) VALUES ({idx}, '{categoria}');")

    for idx, genero in enumerate(generos, start=1):
        genero = genero.replace("'", "''")
        consultas_genero.append(f"INSERT INTO generos (id, nombre) VALUES ({idx}, '{genero}');")

    return consultas_categoria, consultas_genero

# Función para generar consultas INSERT para contenido y su relación con géneros
def generar_inserts_contenido(json_file, categoria_map, genero_map):
    with open(json_file, 'r', encoding='utf-8') as file:
        datos = json.load(file)

    columnas_excluidas = {'categoria', 'genero', 'gen', 'reparto', 'busqueda','resumen'}
    columnas = [col for col in datos[0].keys() if col not in columnas_excluidas]
    columnas.append('id_categoria')

    consultas_contenido = []
    consultas_genero = []

    for entrada in datos:
        valores = []
        for col in columnas:
            if col == 'id_categoria':
                id_categoria = categoria_map.get(entrada['categoria'], 'NULL')
                valores.append(str(id_categoria))
            else:
                valor = entrada[col]
                if isinstance(valor, str):
                    valor = valor.replace("'", "''")
                    valores.append(f"'{valor}'")
                else:
                    valores.append(str(valor))

        insert_query_contenido = f"INSERT INTO contenido ({', '.join(columnas)}) VALUES ({', '.join(valores)});"
        consultas_contenido.append(insert_query_contenido)

        contenido_id = entrada['id']
        genero_ids = [genero_map.get(g.strip(), 'NULL') for g in entrada['genero'].split(', ')]

        for genero_id in genero_ids:
            if genero_id != 'NULL':
                consultas_genero.append(f"INSERT INTO contenido_generos (contenido_id, genero_id) VALUES ({contenido_id}, {genero_id});")

    return consultas_contenido, consultas_genero

# Función para generar consultas INSERT para actores y la relación contenido_actores
def generar_inserts_actores(json_file):
    with open(json_file, 'r', encoding='utf-8') as file:
        datos = json.load(file)

    actores_unicos = {}
    consultas_actores = []
    consultas_contenido_actores = []

    actor_id_counter = 1

    for entrada in datos:
        contenido_id = entrada['id']
        actores = [actor.strip() for actor in entrada['reparto'].split(',')]

        for actor in actores:
            if actor not in actores_unicos:
                actores_unicos[actor] = actor_id_counter
                actor_escaped = actor.replace("'", "''")
                consultas_actores.append(f"INSERT INTO actores (id, nombre) VALUES ({actor_id_counter}, '{actor_escaped}');")
                actor_id_counter += 1

            actor_id = actores_unicos[actor]
            consultas_contenido_actores.append(f"INSERT INTO contenido_actores (contenido_id, actor_id) VALUES ({contenido_id}, {actor_id});")

    return consultas_actores, consultas_contenido_actores

# Mapeos de categorías y géneros a sus respectivos IDs
categoria_map = {
    "Serie": 1,
    "Película": 2
}

genero_map = {
    "Acción": 1,
    "Drama": 2,
    "Fantasía": 3,
    "Ciencia Ficción": 4,
    "Suspenso": 5,
    "Comedia": 6,
    "Misterio": 7,
    "Aventura": 8,
    "Crimen": 9,
    "Familia": 10
}

# Uso del script
json_file = 'trailerflix.json'

# Extraer y generar consultas para categorías y géneros
categorias, generos = extraer_categorias_y_generos(json_file)
consultas_categoria, consultas_genero = generar_inserts_categorias_generos(categorias, generos)

# Generar consultas para contenido y relaciones con géneros
consultas_contenido, consultas_contenido_genero = generar_inserts_contenido(json_file, categoria_map, genero_map)

# Generar consultas para actores y relaciones con el contenido
consultas_actores, consultas_contenido_actores = generar_inserts_actores(json_file)

# Imprimir o ejecutar las consultas generadas
print("Consultas para la tabla Categorías:")
for consulta in consultas_categoria:
    print(consulta)

print("\nConsultas para la tabla Géneros:")
for consulta in consultas_genero:
    print(consulta)

print("\nConsultas para la tabla Contenido:")
for consulta in consultas_contenido:
    print(consulta)

print("\nConsultas para la tabla Contenido_Géneros:")
for consulta in consultas_contenido_genero:
    print(consulta)

print("\nConsultas para la tabla Actores:")
for consulta in consultas_actores:
    print(consulta)

print("\nConsultas para la tabla Contenido_Actores:")
for consulta in consultas_contenido_actores:
    print(consulta)
# Out:
# Consultas para la tabla Categorías:
# INSERT INTO categorias (id, nombre) VALUES (1, 'Serie');
# INSERT INTO categorias (id, nombre) VALUES (2, 'Película');
#
# Consultas para la tabla Géneros:
# INSERT INTO generos (id, nombre) VALUES (1, 'Familia');
# INSERT INTO generos (id, nombre) VALUES (2, 'Suspenso');
# INSERT INTO generos (id, nombre) VALUES (3, 'Intriga');
# INSERT INTO generos (id, nombre) VALUES (4, 'Ficción');
# INSERT INTO generos (id, nombre) VALUES (5, 'Sucesos');
# INSERT INTO generos (id, nombre) VALUES (6, 'Comedia');
# INSERT INTO generos (id, nombre) VALUES (7, 'Futurista');
# INSERT INTO generos (id, nombre) VALUES (8, 'Romance');
# INSERT INTO generos (id, nombre) VALUES (9, 'Historia');
# INSERT INTO generos (id, nombre) VALUES (10, 'Terror');
# INSERT INTO generos (id, nombre) VALUES (11, '¿Ficción?');
# INSERT INTO generos (id, nombre) VALUES (12, 'Misterio');
# INSERT INTO generos (id, nombre) VALUES (13, 'Drama');
# INSERT INTO generos (id, nombre) VALUES (14, 'Acción');
# INSERT INTO generos (id, nombre) VALUES (15, 'Fantasía');
# INSERT INTO generos (id, nombre) VALUES (16, 'Crimen');
# INSERT INTO generos (id, nombre) VALUES (17, 'Western');
# INSERT INTO generos (id, nombre) VALUES (18, 'Ciencia Ficción');
# INSERT INTO generos (id, nombre) VALUES (19, 'Suceso Real');
# INSERT INTO generos (id, nombre) VALUES (20, 'Musical');
# INSERT INTO generos (id, nombre) VALUES (21, 'Aventura');
# INSERT INTO generos (id, nombre) VALUES (22, 'Animación');
# INSERT INTO generos (id, nombre) VALUES (23, 'Tecnología');
# INSERT INTO generos (id, nombre) VALUES (24, 'Sci-Fi');
# INSERT INTO generos (id, nombre) VALUES (25, 'Música');
# INSERT INTO generos (id, nombre) VALUES (26, 'Ciencia ficción');
#
# Consultas para la tabla Contenido:
# INSERT INTO contenido (id, poster, titulo, temporadas, trailer, id_categoria) VALUES (3, './posters/3.jpg', 'The Mandalorian', 2, 'https://www.youtube.com/embed/aOC8E8z_ifw', 1);
# INSERT INTO contenido (id, poster, titulo, temporadas, trailer, id_categoria) VALUES

# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (74, 6);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (74, 8);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (74, 3);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (75, 8);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (75, 1);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (75, 5);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (75, 9);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (75, 2);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (76, 2);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (78, 8);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (78, 4);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (78, 6);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (78, 10);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (78, 1);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (79, 2);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (80, 6);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (80, 2);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (81, 5);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (81, 7);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (82, 8);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (82, 1);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (83, 8);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (83, 1);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (84, 10);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (84, 8);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (84, 1);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (85, 10);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (85, 8);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (85, 6);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (86, 10);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (86, 8);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (86, 6);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (87, 2);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (87, 5);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (88, 2);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (88, 5);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (89, 8);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (89, 2);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (89, 5);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (89, 7);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (90, 6);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (90, 10);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (90, 1);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (91, 2);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (92, 10);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (92, 6);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (93, 10);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (93, 6);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (94, 10);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (94, 6);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (95, 10);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (95, 6);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (96, 5);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (96, 2);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (97, 2);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (97, 5);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (98, 10);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (98, 6);
# INSERT INTO contenido_generos (contenido_id, genero_id) VALUES (98, 3);
#
# Consultas para la tabla Actores:
# INSERT INTO actores (id, nombre) VALUES (1, 'Pedro Pascal');
# INSERT INTO actores (id, nombre) VALUES (2, 'Carl Weathers');
# INSERT INTO actores (id, nombre) VALUES (3, 'Misty Rosas');
# INSERT INTO actores (id, nombre) VALUES (4, 'Chris Bartlett');
# INSERT INTO actores (id, nombre) VALUES (5, 'Rio Hackford');
# INSERT INTO actores (id, nombre) VALUES (6, 'Giancarlo Esposito');
# INSERT INTO actores (id, nombre) VALUES (7, 'Tom Hopper');
# INSERT INTO actores (id, nombre) VALUES (8, 'David Castañeda');
# INSERT INTO actores (id, nombre) VALUES (9, 'Emmy Raver-Lampman');
# INSERT INTO actores (id, nombre) VALUES (10, 'Robert Sheehan');
# INSERT INTO actores (id, nombre) VALUES (11, 'Aidan Gallagher');
# INSERT INTO actores (id, nombre) VALUES (12, 'Elliot Page');
# INSERT INTO actores (id, nombre) VALUES (13, 'Anya Taylor-Joy');
# INSERT INTO actores (id, nombre) VALUES (14, 'Thomas Brodie-Sangster');
# INSERT INTO actores (id, nombre) VALUES (15, 'Harry Melling');
# INSERT INTO actores (id, nombre) VALUES (16, 'Moses Ingram');
# INSERT INTO actores (id, nombre) VALUES (17, 'Chloe Pirrie');
# INSERT INTO actores (id, nombre) VALUES (18, 'Janina Elkin');
# INSERT INTO actores (id, nombre) VALUES (19, 'Lili Reinhart');
# INSERT INTO actores (id, nombre) VALUES (20, 'Casey Cott');
# INSERT INTO actores (id, nombre) VALUES (21, 'Camila Mendes');
# INSERT INTO actores (id, nombre) VALUES (22, 'Marisol Nichols');
# INSERT INTO actores (id, nombre) VALUES (23, 'Madelaine Petsch');
# INSERT INTO actores (id, nombre) VALUES (24, 'Mädchen Amick');
# INSERT INTO actores (id, nombre) VALUES (25, 'Claire Fox');
# INSERT INTO actores (id, nombre) VALUES (26, 'Olivia Colman');
# INSERT INTO actores (id, nombre) VALUES (27, 'Matt Smith');
# INSERT INTO actores (id, nombre) VALUES (28, 'Tobias Menzies');
# INSERT INTO actores (id, nombre) VALUES (29, 'Vanesa Kirby');
# INSERT INTO actores (id, nombre) VALUES (30, 'Helena Bonham Carter');
# INSERT INTO actores (id, nombre) VALUES (31, 'Millie Bobby Brown');
# INSERT INTO actores (id, nombre) VALUES (32, 'Henry Cavill');
# INSERT INTO actores (id, nombre) VALUES (33, 'Sam Claflin');
# INSERT INTO actores (id, nombre) VALUES (34, 'Louis Partridge');
# INSERT INTO actores (id, nombre) VALUES (35, 'Adeel Akhtar');
# INSERT INTO actores (id, nombre) VALUES (36, 'Joaquin Phoenix');
# INSERT INTO actores (id, nombre) VALUES (37, 'Robert De Niro');
# INSERT INTO actores (id, nombre) VALUES (38, 'Zazie Beetz');
# INSERT INTO actores (id, nombre) VALUES (39, 'Frances Conroy');
# INSERT INTO actores (id, nombre) VALUES (40, 'Brett Cullen');
# INSERT INTO actores (id, nombre) VALUES (41, 'Shea Whigham');
# INSERT INTO actores (id, nombre) VALUES (42, 'Robert Downey Jr.');
# INSERT INTO actores (id, nombre) VALUES (43, 'Chris Evans');
# INSERT INTO actores (id, nombre) VALUES (44, 'Mark Ruffalo');
# INSERT INTO actores (id, nombre) VALUES (45, 'Chris Hemsworth');
# INSERT INTO actores (id, nombre) VALUES (46, 'Scarlett Johansson');
# INSERT INTO actores (id, nombre) VALUES (47, 'Jeremy Renner');
# INSERT INTO actores (id, nombre) VALUES (48, 'Emilia Clarke');
# INSERT INTO actores (id, nombre) VALUES (49, 'Lena Headey');
# INSERT INTO actores (id, nombre) VALUES (50, 'Sophie Turner');
# INSERT INTO actores (id, nombre) VALUES (51, 'Kit Harington');
# INSERT INTO actores (id, nombre) VALUES (52, 'Peter Dinklage');
# INSERT INTO actores (id, nombre) VALUES (53, 'Nikolaj Coster-Waldau');
# INSERT INTO actores (id, nombre) VALUES (54, 'Grant Gustin');
# INSERT INTO actores (id, nombre) VALUES (55, 'Carlos Valdes');
# INSERT INTO actores (id, nombre) VALUES (56, 'Danielle Panabaker');
# INSERT INTO actores (id, nombre) VALUES (57, 'Candice Patton');
# INSERT INTO actores (id, nombre) VALUES (58, 'Jesse L. Martin');
# INSERT INTO actores (id, nombre) VALUES (59, 'Tom Cavanagh');
# INSERT INTO actores (id, nombre) VALUES (60, 'Jim Parsons');
# INSERT INTO actores (id, nombre) VALUES (61, 'Johnny Galecki');
# INSERT INTO actores (id, nombre) VALUES (62, 'Kaley Cuoco');
# INSERT INTO actores (id, nombre) VALUES (63, 'Simon Helberg');
# INSERT INTO actores (id, nombre) VALUES (64, 'Kunal Nayyar');
# INSERT INTO actores (id, nombre) VALUES (65, 'Melissa Rauch');
# INSERT INTO actores (id, nombre) VALUES (66, 'Mayim Bialik');
# INSERT INTO actores (id, nombre) VALUES (67, 'Jennifer Aniston');
# INSERT INTO actores (id, nombre) VALUES (68, 'Courteney Cox');
# INSERT INTO actores (id, nombre) VALUES (69, 'Lisa Kudrow');
# INSERT INTO actores (id, nombre) VALUES (70, 'David Schwimmer');
# INSERT INTO actores (id, nombre) VALUES (71, 'Matthew Perry');
# INSERT INTO actores (id, nombre) VALUES (72, 'Matt LeBlanc');
# INSERT INTO actores (id, nombre) VALUES (73, 'Amybeth McNulty');
# INSERT INTO actores (id, nombre) VALUES (74, 'Geraldine James');
# INSERT INTO actores (id, nombre) VALUES (75, 'R. H. Thomson');
# INSERT INTO actores (id, nombre) VALUES (76, 'Corrine Koslo');
# INSERT INTO actores (id, nombre) VALUES (77, 'Dalila Bela');
# INSERT INTO actores (id, nombre) VALUES (78, 'Lucas Jade Zumann');
# INSERT INTO actores (id, nombre) VALUES (79, 'Gillian Anderson');
# INSERT INTO actores (id, nombre) VALUES (80, 'David Duchovny');
# INSERT INTO actores (id, nombre) VALUES (81, 'Mitch Pileggi');
# INSERT INTO actores (id, nombre) VALUES (82, 'Robert Patrick');
# INSERT INTO actores (id, nombre) VALUES (83, 'Tom Braidwood');
# INSERT INTO actores (id, nombre) VALUES (84, 'Bruce Harwood');
# INSERT INTO actores (id, nombre) VALUES (85, 'Jared Harris');
# INSERT INTO actores (id, nombre) VALUES (86, 'Stellan Skarsgård');
# INSERT INTO actores (id, nombre) VALUES (87, 'Emily Watson');
# INSERT INTO actores (id, nombre) VALUES (88, 'Paul Ritter');
# INSERT INTO actores (id, nombre) VALUES (89, 'Jessie Buckley');
# INSERT INTO actores (id, nombre) VALUES (90, 'Adam Nagaitis');
# INSERT INTO actores (id, nombre) VALUES (91, 'Evan Rachel Wood');
# INSERT INTO actores (id, nombre) VALUES (92, 'Thandiwe Newton');
# INSERT INTO actores (id, nombre) VALUES (93, 'Jeffrey Wright');
# INSERT INTO actores (id, nombre) VALUES (94, 'Tessa Thompson');
# INSERT INTO actores (id, nombre) VALUES (95, 'Ed Harris');
# INSERT INTO actores (id, nombre) VALUES (96, 'Luke Hemsworth');
# INSERT INTO actores (id, nombre) VALUES (97, 'Rodrigo Santoro');
# INSERT INTO actores (id, nombre) VALUES (98, 'Simon Quarterman');
# INSERT INTO actores (id, nombre) VALUES (99, 'Clifton Collins Jr.');
# INSERT INTO actores (id, nombre) VALUES (100, 'Anthony Hopkins');
# INSERT INTO actores (id, nombre) VALUES (101, 'Ingrid Bolsø Berdal');
# INSERT INTO actores (id, nombre) VALUES (102, 'Angela Sarafyan');
# INSERT INTO actores (id, nombre) VALUES (103, 'Shannon Woodward');
# INSERT INTO actores (id, nombre) VALUES (104, 'Talulah Riley');
# INSERT INTO actores (id, nombre) VALUES (105, 'Louis Herthum');
# INSERT INTO actores (id, nombre) VALUES (106, 'Ben Barnes');
# INSERT INTO actores (id, nombre) VALUES (107, 'Jimmi Simpson');
# INSERT INTO actores (id, nombre) VALUES (108, 'Leonardo Nam');
# INSERT INTO actores (id, nombre) VALUES (109, 'Aaron Paul');
# INSERT INTO actores (id, nombre) VALUES (110, 'Vincent Cassel');
# INSERT INTO actores (id, nombre) VALUES (111, 'Izabella Alvarez');
# INSERT INTO actores (id, nombre) VALUES (112, 'Jeff Daniel Phillips');
# INSERT INTO actores (id, nombre) VALUES (113, 'Lee Pace');
# INSERT INTO actores (id, nombre) VALUES (114, 'Scoot McNairy');
# INSERT INTO actores (id, nombre) VALUES (115, 'Mackenzie Davis');
# INSERT INTO actores (id, nombre) VALUES (116, 'Kerry Bishé');
# INSERT INTO actores (id, nombre) VALUES (117, 'Toby Huss');
# INSERT INTO actores (id, nombre) VALUES (118, 'Alana Cavanaugh');
# INSERT INTO actores (id, nombre) VALUES (119, 'Jessica Chastain');
# INSERT INTO actores (id, nombre) VALUES (120, 'John Malkovich');
# INSERT INTO actores (id, nombre) VALUES (121, 'Colin Farrell');
# INSERT INTO actores (id, nombre) VALUES (122, 'Common');
# INSERT INTO actores (id, nombre) VALUES (123, 'Geena Davis');
# INSERT INTO actores (id, nombre) VALUES (124, 'Ioan Gruffudd');
# INSERT INTO actores (id, nombre) VALUES (125, 'Margot Robbie');
# INSERT INTO actores (id, nombre) VALUES (126, 'Ewan McGregor');
# INSERT INTO actores (id, nombre) VALUES (127, 'Mary Elizabeth Winstead');
# INSERT INTO actores (id, nombre) VALUES (128, 'Jurnee Smollett');
# INSERT INTO actores (id, nombre) VALUES (129, 'Rosie Perez');
# INSERT INTO actores (id, nombre) VALUES (130, 'Chris Messina');
# INSERT INTO actores (id, nombre) VALUES (131, 'Stacy Martin');
# INSERT INTO actores (id, nombre) VALUES (132, 'Rhona Mitra');
# INSERT INTO actores (id, nombre) VALUES (133, 'Theo James');
# INSERT INTO actores (id, nombre) VALUES (134, 'Peter Ferdinando');
# INSERT INTO actores (id, nombre) VALUES (135, 'Lia Williams');
# INSERT INTO actores (id, nombre) VALUES (136, 'Toby Jones');
# INSERT INTO actores (id, nombre) VALUES (137, 'Miranda Cosgrove');
# INSERT INTO actores (id, nombre) VALUES (138, 'Kate Walsh');
# INSERT INTO actores (id, nombre) VALUES (139, 'Omar Epps');
# INSERT INTO actores (id, nombre) VALUES (140, 'Angus Macfadyen');
# INSERT INTO actores (id, nombre) VALUES (141, 'Jorja Fox');
# INSERT INTO actores (id, nombre) VALUES (142, 'Enver Gjokaj');
# INSERT INTO actores (id, nombre) VALUES (143, 'Bill Skarsgård');
# INSERT INTO actores (id, nombre) VALUES (144, 'Bill Hader');
# INSERT INTO actores (id, nombre) VALUES (145, 'James McAvoy');
# INSERT INTO actores (id, nombre) VALUES (146, 'Isaiah Mustafa');
# INSERT INTO actores (id, nombre) VALUES (147, 'Jay Ryan');
# INSERT INTO actores (id, nombre) VALUES (148, 'Chadwick Boseman');
# INSERT INTO actores (id, nombre) VALUES (149, 'Michael B. Jordan');
# INSERT INTO actores (id, nombre) VALUES (150, 'Lupita Nyong''o');
# INSERT INTO actores (id, nombre) VALUES (151, 'Danai Gurira');
# INSERT INTO actores (id, nombre) VALUES (152, 'Martin Freeman');
# INSERT INTO actores (id, nombre) VALUES (153, 'Daniel Kaluuya');
# INSERT INTO actores (id, nombre) VALUES (154, 'Christian Bale');
# INSERT INTO actores (id, nombre) VALUES (155, 'Matt Damon');
# INSERT INTO actores (id, nombre) VALUES (156, 'Caitriona Balfe');
# INSERT INTO actores (id, nombre) VALUES (157, 'Josh Lucas');
# INSERT INTO actores (id, nombre) VALUES (158, 'Noah Jupe');
# INSERT INTO actores (id, nombre) VALUES (159, 'Jon Bernthal');
# INSERT INTO actores (id, nombre) VALUES (160, 'Génesis Rodríguez');
# INSERT INTO actores (id, nombre) VALUES (161, 'Vincent Piazza');
# INSERT INTO actores (id, nombre) VALUES (162, 'Benjamin Sokolow');
# INSERT INTO actores (id, nombre) VALUES (163, 'Emily Bayiokos');
# INSERT INTO actores (id, nombre) VALUES (164, 'Amy Manson');
# INSERT INTO actores (id, nombre) VALUES (165, 'Luke Allen-Gale');
# INSERT INTO actores (id, nombre) VALUES (166, 'Nina Bergman');
# INSERT INTO actores (id, nombre) VALUES (167, 'Dominic Mafham');
# INSERT INTO actores (id, nombre) VALUES (168, 'James Weber Brown');
# INSERT INTO actores (id, nombre) VALUES (169, 'Lorina Kamburova');
# INSERT INTO actores (id, nombre) VALUES (170, 'Marion Cotillard');
# INSERT INTO actores (id, nombre) VALUES (171, 'Laurence Fishburne');
# INSERT INTO actores (id, nombre) VALUES (172, 'Jude Law');
# INSERT INTO actores (id, nombre) VALUES (173, 'Kate Winslet');
# INSERT INTO actores (id, nombre) VALUES (174, 'Jennifer Ehle');
# INSERT INTO actores (id, nombre) VALUES (175, 'Gwyneth Paltrow');
# INSERT INTO actores (id, nombre) VALUES (176, 'Florence Pugh');
# INSERT INTO actores (id, nombre) VALUES (177, 'David Harbour');
# INSERT INTO actores (id, nombre) VALUES (178, 'O.T. Fagbenle');
# INSERT INTO actores (id, nombre) VALUES (179, 'Rachel Weisz');
# INSERT INTO actores (id, nombre) VALUES (180, 'William Hurt');
# INSERT INTO actores (id, nombre) VALUES (181, 'Ray Winstone');
# INSERT INTO actores (id, nombre) VALUES (182, 'Kristen Wiig');
# INSERT INTO actores (id, nombre) VALUES (183, 'Jeff Daniels');
# INSERT INTO actores (id, nombre) VALUES (184, 'Michael Peña');
# INSERT INTO actores (id, nombre) VALUES (185, 'Sean Bean');
# INSERT INTO actores (id, nombre) VALUES (186, 'Kate Mara');
# INSERT INTO actores (id, nombre) VALUES (187, 'Alicia Vikander');
# INSERT INTO actores (id, nombre) VALUES (188, 'Domhnall Gleeson');
# INSERT INTO actores (id, nombre) VALUES (189, 'Oscar Isaac');
# INSERT INTO actores (id, nombre) VALUES (190, 'Sonoya Mizuno');
# INSERT INTO actores (id, nombre) VALUES (191, 'Corey Johnson');
# INSERT INTO actores (id, nombre) VALUES (192, 'Claire Selby');
# INSERT INTO actores (id, nombre) VALUES (193, 'Gana Bayarsaikhan');
# INSERT INTO actores (id, nombre) VALUES (194, 'Bryce Dallas Howard');
# INSERT INTO actores (id, nombre) VALUES (195, 'Chris Pratt');
# INSERT INTO actores (id, nombre) VALUES (196, 'Irrfan Khan');
# INSERT INTO actores (id, nombre) VALUES (197, 'Vincent D''Onofrio');
# INSERT INTO actores (id, nombre) VALUES (198, 'Omar Sy');
# INSERT INTO actores (id, nombre) VALUES (199, 'Nick Robinson');
# INSERT INTO actores (id, nombre) VALUES (200, 'Judy Greer');
# INSERT INTO actores (id, nombre) VALUES (201, 'Will Smith');
# INSERT INTO actores (id, nombre) VALUES (202, 'Alice Braga');
# INSERT INTO actores (id, nombre) VALUES (203, 'Charlie Tahan');
# INSERT INTO actores (id, nombre) VALUES (204, 'Dash Mihok');
# INSERT INTO actores (id, nombre) VALUES (205, 'Salli Richardson-Whitfield');
# ...
# INSERT INTO contenido_actores (contenido_id, actor_id) VALUES (78, 655);
# INSERT INTO contenido_actores (contenido_id, actor_id) VALUES